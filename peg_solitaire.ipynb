# %%
from peg_board import *
from search4e import *

# %%
class PegSolitaire(Problem):
    """PegSoltaire, a subclass of Problem, is used to find a solution to a Peg Solitaire puzzle.
    It initializes the board according to the input shape, checks legal moves,
    performs actions, compares the state with the goal, and defines three heuristics."""
    def __init__(self, shape='English'):
        assert shape == 'English' or shape == 'Triangle'
        if shape == 'English':
            board = EnglishPegBoard()
        elif shape == 'Triangle':
            board = TrianglePegBoard()

        self.initial = board
        self.goal = board.init_hole

    def actions(self, board):
        """Return a collection of the allowable moves from this state."""
        return board.actions()

    def result(self, board, action):
        """Return the state that results from making a move from a state."""
        return board.result(action)

    def is_goal(self, board):
        """Return True if this is a final state for the game."""
        return len(board.pegs) == 1 and self.goal in board.pegs

   # def action_cost(self, s, a, s1):
   #      """Return the value of this final state to player."""
   #      return 1

    def h1(self, board):
        # peg count heuristic
        return len(board.pegs) - 1

    def h2(self, board):
        # distance heuristic
        gi, gj = self.goal
        return sum(abs(i-gi) + abs(j-gj) for (i,j) in board.pegs)

    def h3(self, board):
        # dead pegs heuristic
        return board.dead_count()

    def h(self, node):
        board = node.state
        return (
            1.0 * self.h1(board) +
            0.1 * self.h2(board) +
            0.5 * self.h3(board)
        )

# %%
peg_sol = PegSolitaire()
# for s in path_states(breadth_first_bfs(peg_sol)): # 2 hours still running
#     print(s)
# for s in path_states(depth_first_bfs(peg_sol)): # 2m 41s
#     print(s)
# for s in path_states(iterative_deepening_search(peg_sol)): # 1 hour still running
#     print(s)
for s in path_states(astar_search(peg_sol)): # 27s
    print(s)
for s in path_states(greedy_bfs(peg_sol)): # 29s
    print(s)
# Out:
# _ _ X X X _ _
# _ _ X X X _ _
# X X X X X X X
# X X X O X X X
# X X X X X X X
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# X X X X X X X
# X O O X X X X
# X X X X X X X
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X O X X X X
# X O X X X X X
# X X X X X X X
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O O X X
# X O X X X X X
# X X X X X X X
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O X X X
# X O X X O X X
# X X X X O X X
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O X X X
# X O X X O X X
# X X O O X X X
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O X X X
# X O X X X X X
# X X O O O X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O O X X
# X O X X O X X
# X X O O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O O X X
# X O X X X O O
# X X O O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O O X X
# X O X X X O O
# O O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# O X X O O X X
# O O X X X O O
# X O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X O _ _
# _ _ O X O _ _
# O X X O X X X
# O O X X X O O
# X O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X O _ _
# _ _ O X X _ _
# O X X O O X X
# O O X X O O O
# X O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X O _ _
# _ _ O X X _ _
# O X X O X O O
# O O X X O O O
# X O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X X X O O
# X O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X X X O O
# X O X X X X X
# _ _ X O O _ _
# _ _ X O X _ _
# _ _ X X O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X X O O O
# X O X X O X X
# _ _ X O X _ _
# _ _ X O X _ _
# _ _ X X O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X X O O O
# X O X X X O O
# _ _ X O X _ _
# _ _ X O X _ _
# _ _ X X O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X X O O O
# X O X O O X O
# _ _ X O X _ _
# _ _ X O X _ _
# _ _ X X O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X X O O O
# X O X O X X O
# _ _ X O O _ _
# _ _ X O O _ _
# _ _ X X O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X X O O O
# X O X X O O O
# _ _ X O O _ _
# _ _ X O O _ _
# _ _ X X O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X X O O O
# X X O O O O O
# _ _ X O O _ _
# _ _ X O O _ _
# _ _ X X O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X X O O O
# X X X O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ X O O _ _
# _ _ O O O _ _
# O X X X O O O
# O O X X O O O
# X X X O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ X O O _ _
# _ _ O O O _ _
# O X X X O O O
# O O O X O O O
# X X O O O O O
# _ _ X O O _ _
# _ _ O O O _ _
# _ _ X O O _ _
# _ _ O O O _ _
# O X X X O O O
# O O O X O O O
# O O X O O O O
# _ _ X O O _ _
# _ _ O O O _ _
# _ _ X O O _ _
# _ _ O O O _ _
# O X X X O O O
# O O X X O O O
# O O O O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ X O O _ _
# _ _ X O O _ _
# O X O X O O O
# O O O X O O O
# O O O O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O O O _ _
# O X X X O O O
# O O O X O O O
# O O O O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O O O O O O
# O O O O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O X O _ _
# O O O X O O O
# O O O O O O O
# O O O O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O O O _ _
# O O O O O O O
# O O O X O O O
# O O O O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ X X X _ _
# _ _ X X X _ _
# X X X X X X X
# X X X O X X X
# X X X X X X X
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# X X X X X X X
# X O O X X X X
# X X X X X X X
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X O X X X X
# X O X X X X X
# X X X X X X X
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O O X X
# X O X X X X X
# X X X X X X X
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O X X X
# X O X X O X X
# X X X X O X X
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O X X X
# X O X X O X X
# X X O O X X X
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O X X X
# X O X X X X X
# X X O O O X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O O X X
# X O X X O X X
# X X O O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O O X X
# X O X X X O O
# X X O O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# X X X O O X X
# X O X X X O O
# O O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X X _ _
# _ _ O X X _ _
# O X X O O X X
# O O X X X O O
# X O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X O _ _
# _ _ O X O _ _
# O X X O X X X
# O O X X X O O
# X O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X O _ _
# _ _ O X X _ _
# O X X O O X X
# O O X X O O O
# X O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X O _ _
# _ _ O X X _ _
# O X X O X O O
# O O X X O O O
# X O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X X O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X X X O O
# X O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X O O _ _
# _ _ O O O _ _
# O X X X O O O
# O O X X X O O
# X O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X O X O O
# X O X O X X X
# _ _ X X O _ _
# _ _ X X X _ _
# _ _ X O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X O X O O
# X O X X X X X
# _ _ X O O _ _
# _ _ X O X _ _
# _ _ X O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X O O O O
# X O X X O X X
# _ _ X O X _ _
# _ _ X O X _ _
# _ _ X O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X O O O O
# X O X X X O O
# _ _ X O X _ _
# _ _ X O X _ _
# _ _ X O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X O O O O
# X O X O O X O
# _ _ X O X _ _
# _ _ X O X _ _
# _ _ X O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X O O O O
# X O X O X X O
# _ _ X O O _ _
# _ _ X O O _ _
# _ _ X O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X O O O O
# X O X X O O O
# _ _ X O O _ _
# _ _ X O O _ _
# _ _ X O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X O O O O
# X X O O O O O
# _ _ X O O _ _
# _ _ X O O _ _
# _ _ X O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X O O O O
# X X X O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ X O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O O O O O O
# X X O O O O O
# _ _ X O O _ _
# _ _ O O O _ _
# _ _ X O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O O O O O O
# O O X O O O O
# _ _ X O O _ _
# _ _ O O O _ _
# _ _ X O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O X O O O O
# O O O O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ X O O _ _
# _ _ X X O _ _
# O X O O O O O
# O O O O O O O
# O O O O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O X O _ _
# O X X O O O O
# O O O O O O O
# O O O O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O X O _ _
# O O O X O O O
# O O O O O O O
# O O O O O O O
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O O O _ _
# _ _ O O O _ _
# O O O O O O O
# O O O X O O O
# O O O O O O O
# _ _ O O O _ _
# _ _ O O O _ _
