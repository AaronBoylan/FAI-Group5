# %%
from peg_board import *
from games4e import *

# %%
class PegDuotaire(Game):
    """PegDuotaire, a subclass of Game, represents one player in a Peg Duotaire game."""
    def __init__(self, shape='English'):
        assert shape == 'English' or shape == 'Triangle'
        self.shape = shape
        if shape == 'English':
            # board = EnglishPegBoardDict(to_move='X')
            board = EnglishPegBoardInt(to_move='X')
        elif shape == 'French':
            board = FrenchPegBoardInt(to_move='X')
        elif shape == 'Triangle':
            # board = TrianglePegBoardDict(to_move='X')
            board = TrianglePegBoardInt(to_move='X')

        self.initial = board
        if isinstance(board, PegBoardDict):
            self.goal = board.init_hole
        else:
            self.goal = copy.copy(self.initial)
            self.goal.state = 1 << board.GOAL_INDEX
            self.goal.pagoda = self.goal.compute_pagoda(self.goal.state)
            self.goal.__dict__.pop("_canon", None)
            self.goal.__dict__.pop("_hash", None)

    def actions(self, board):
        """Return a collection of the allowable moves from this state."""
        return board.actions()

    def result(self, board, action):
        """Return the state that results from making a move from a state."""
        new_board = board.result(action)
        new_board.to_move = 'O' if board.to_move == 'X' else 'X'
        return new_board

    def is_terminal(self, board):
        """Return True if this is a final state for the game."""
        return len(board.actions()) == 0

    def terminal_test(self, board):
        return self.is_terminal(board)

    def to_move(self, board):
        return board.to_move

    def utility(self, board, player):
        """Return the value of this final state to player."""
        if board.to_move == player:
            return -1
        else:
            return 1

# %%
peg_duo = PegDuotaire()
# final_board = play_game(peg_duo, dict(X=random_player, O=random_player), verbose=True)
final_board = play_game(peg_duo, dict(X=player(monte_carlo_tree_search), O=random_player), verbose=True)
#final_board = play_game(peg_duo, dict(X=random_player, O=player(alphabeta_search)), verbose=True)  # take very long time for one step
print(f'Utility of X is: {peg_duo.utility(final_board, "X")}')
# Out:
# (16384, 32768, 65536, 0)
# Player X move: (16384, 32768, 65536, 0)
#     X X X
#     X X X
# X X X X X X X
# X O O X X X X
# X X X X X X X
#     X X X
#     X X X
# Player O move: (131072, 65536, 32768, -2)
#     X X X
#     X X X
# X X X X X X X
# X O X O O X X
# X X X X X X X
#     X X X
#     X X X
# (268435456, 8388608, 65536, 0)
# Player X move: (268435456, 8388608, 65536, 0)
#     X X X
#     X X X
# X X X X X X X
# X O X X O X X
# X X X O X X X
#     X O X
#     X X X
# Player O move: (32768, 65536, 131072, -2)
#     X X X
#     X X X
# X X X X X X X
# X O O O X X X
# X X X O X X X
#     X O X
#     X X X
# (2097152, 4194304, 8388608, 0)
# Player X move: (2097152, 4194304, 8388608, 0)
#     X X X
#     X X X
# X X X X X X X
# X O O O X X X
# X O O X X X X
#     X O X
#     X X X
# Player O move: (1073741824, 134217728, 4194304, 0)
#     X X X
#     X X X
# X X X X X X X
# X O O O X X X
# X O X X X X X
#     O O X
#     O X X
# (4294967296, 2147483648, 1073741824, 0)
# Player X move: (4294967296, 2147483648, 1073741824, 0)
#     X X X
#     X X X
# X X X X X X X
# X O O O X X X
# X O X X X X X
#     O O X
#     X O O
# Player O move: (16777216, 536870912, 4294967296, 0)
#     X X X
#     X X X
# X X X X X X X
# X O O O X X X
# X O X X O X X
#     O O O
#     X O X
# (262144, 131072, 65536, 0)
# Player X move: (262144, 131072, 65536, 0)
#     X X X
#     X X X
# X X X X X X X
# X O O X O O X
# X O X X O X X
#     O O O
#     X O X
# Player O move: (4194304, 8388608, 16777216, -1)
#     X X X
#     X X X
# X X X X X X X
# X O O X O O X
# X O O O X X X
#     O O O
#     X O X
# (8, 256, 32768, 0)
# Player X move: (8, 256, 32768, 0)
#     X X X
#     O X X
# X X O X X X X
# X O X X O O X
# X O O O X X X
#     O O O
#     X O X
# Player O move: (512, 65536, 8388608, -2)
#     X X X
#     O X X
# X X O O X X X
# X O X O O O X
# X O O X X X X
#     O O O
#     X O X
# (32, 1024, 131072, 0)
# Player X move: (32, 1024, 131072, 0)
#     X X X
#     O X O
# X X O O O X X
# X O X O X O X
# X O O X X X X
#     O O O
#     X O X
# Player O move: (2, 16, 512, 0)
#     X O X
#     O O O
# X X O X O X X
# X O X O X O X
# X O O X X X X
#     O O O
#     X O X
# (64, 128, 256, 0)
# Player X move: (64, 128, 256, 0)
#     X O X
#     O O O
# O O X X O X X
# X O X O X O X
# X O O X X X X
#     O O O
#     X O X
# Player O move: (16777216, 8388608, 4194304, -1)
#     X O X
#     O O O
# O O X X O X X
# X O X O X O X
# X O X O O X X
#     O O O
#     X O X
# (256, 512, 1024, -1)
# Player X move: (256, 512, 1024, -1)
#     X O X
#     O O O
# O O O O X X X
# X O X O X O X
# X O X O O X X
#     O O O
#     X O X
# Player O move: (4194304, 32768, 256, 0)
#     X O X
#     O O O
# O O X O X X X
# X O O O X O X
# X O O O O X X
#     O O O
#     X O X
# (1024, 131072, 16777216, 0)
# Player X move: (1024, 131072, 16777216, 0)
#     X O X
#     O O O
# O O X O O X X
# X O O O O O X
# X O O O X X X
#     O O O
#     X O X
# Player O move: (33554432, 16777216, 8388608, 0)
#     X O X
#     O O O
# O O X O O X X
# X O O O O O X
# X O O X O O X
#     O O O
#     X O X
# (4096, 2048, 1024, 0)
# Player X move: (4096, 2048, 1024, 0)
#     X O X
#     O O O
# O O X O X O O
# X O O O O O X
# X O O X O O X
#     O O O
#     X O X
# Player O move: (1048576, 8192, 64, 0)
#     X O X
#     O O O
# X O X O X O O
# O O O O O O X
# O O O X O O X
#     O O O
#     X O X
# (67108864, 524288, 4096, 0)
# Player X move: (67108864, 524288, 4096, 0)
#     X O X
#     O O O
# X O X O X O X
# O O O O O O O
# O O O X O O O
#     O O O
#     X O X
# Utility of X is: 1
